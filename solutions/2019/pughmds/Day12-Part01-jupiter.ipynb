# %%
import copy

# %%
class Coordinate:
    '''
    Just a object to store coordinates. Nothing fancy
    '''
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z

class Moon:
    '''
    An object containing each moon
    '''
    def __init__(self, name, x, y, z):
        self.name = name
        self.pos = [Coordinate(int(x), int(y), int(z))]
        self.vel = [Coordinate(0, 0, 0)]

    def getPositionAtTime(self, time):
        '''
        returns the moon's position (coordinates) at a given time
        '''
        try:
            return self.pos[time]
        except:
            return None
    
    def getVelocityAtTime(self, time):
        '''
        returns a moon's velocity at a given time.
        '''
        try:
            return self.vel[time]
        except:
            return None
        
    def initTimeStep(self, time_step):
        '''
        initialises the time step provided to be the same as the step before it initially
        '''
        if len(self.pos) <= time_step:
            newpos = copy.deepcopy(self.pos[time_step-1])
            self.pos.append(newpos)
        if len(self.vel) <= time_step:
            newvel = copy.deepcopy(self.vel[time_step-1])
            self.vel.append(newvel)
    
    def getPositionString(self, time_step):
        '''
        Returns the current position of this moon to a string like on the puzzle's page
        '''
        return "x={:3}, y={:3}, z={:3}".format(self.pos[time_step].x, self.pos[time_step].y, self.pos[time_step].z)
    
    def getVelocityString(self, time_step):
        '''
        Returns the current velocity of this moon to a string like on the puzzle's page
        '''
        return "x={:3}, y={:3}, z={:3}".format(self.vel[time_step].x, self.vel[time_step].y, self.vel[time_step].z)
    
    def applyVelocity(self, time_step):
        '''
        Once we calculate the velocity of this position, we need to apply it to the position to update this step
        '''
        self.pos[time_step].x += self.vel[time_step].x
        self.pos[time_step].y += self.vel[time_step].y
        self.pos[time_step].z += self.vel[time_step].z
    
    def getPotentialEnergy(self, time_step):
        '''
        Calculates the potential energy in the moon for a given time step
        '''
        pot = abs(self.pos[time_step].x) + abs(self.pos[time_step].y) + abs(self.pos[time_step].z)
        return pot 
    
    def getKineticEnergy(self, time_step):
        '''
        Calculate the kinetic energy in the moon for a given time step
        '''
        pot = abs(self.vel[time_step].x) + abs(self.vel[time_step].y) + abs(self.vel[time_step].z)
        return pot
        
class System:
    '''
    This will store the information for the entire planetary system
    '''
    def __init__(self, moon_names, scan):
        self.moons = list()
        for idx, pos in enumerate(scan):
            pos_list = pos.replace("<","").replace(">","").replace("x=","").replace("y=","").replace("z=","").split(",")
            self.moons.append(Moon(moon_names[idx], pos_list[0], pos_list[1], pos_list[2]))
        
    def calculateVelocity(self, time_step):
        '''
        This calculates the velocity for the given time step based upon the differences in position.
        I probably could do this more elegantly, but this works for now...
        '''
        for i in range(len(self.moons)):
            self.moons[i].initTimeStep(time_step)
            for j in range(i + 1, len(self.moons)):
                self.moons[j].initTimeStep(time_step)
                if self.moons[i].pos[time_step].x > self.moons[j].pos[time_step].x:
                    self.moons[i].vel[time_step].x -= 1
                    self.moons[j].vel[time_step].x += 1
                elif self.moons[i].pos[time_step].x < self.moons[j].pos[time_step].x:
                    self.moons[i].vel[time_step].x += 1
                    self.moons[j].vel[time_step].x -= 1
                    
                if self.moons[i].pos[time_step].y > self.moons[j].pos[time_step].y:
                    self.moons[i].vel[time_step].y -= 1
                    self.moons[j].vel[time_step].y += 1
                elif self.moons[i].pos[time_step].y < self.moons[j].pos[time_step].y:
                    self.moons[i].vel[time_step].y += 1
                    self.moons[j].vel[time_step].y -= 1
                    
                if self.moons[i].pos[time_step].z > self.moons[j].pos[time_step].z:
                    self.moons[i].vel[time_step].z -= 1
                    self.moons[j].vel[time_step].z += 1
                elif self.moons[i].pos[time_step].z < self.moons[j].pos[time_step].z:
                    self.moons[i].vel[time_step].z += 1
                    self.moons[j].vel[time_step].z -= 1
        
        for moon in self.moons:
            moon.applyVelocity(time_step)
                    
    def getPosition(self, time_step):
        '''
        This will print out the position of the moons at a given time step
        '''
        print("After {} steps:".format(time_step))
        for moon in self.moons:
            if len(moon.name) > 6:
                print("{}:\t pos=<{}>, \t vel=<{}>".format(moon.name, moon.getPositionString(time_step), moon.getVelocityString(time_step)))
            else:
                print("{}:\t\t pos=<{}>, \t vel=<{}>".format(moon.name, moon.getPositionString(time_step), moon.getVelocityString(time_step)))
                    
    def getEnergy(self, time_step, print_step):
        '''
        This will calculate the energy for a given time step and print out the 
        results only if this is a printing step
        '''
        if time_step % print_step == 0:
            print("Energy after {} steps:".format(time_step))
        total = 0
        for moon in self.moons:
            pot = moon.getPotentialEnergy(time_step)
            kin = moon.getKineticEnergy(time_step)
            moon_total = kin * pot
            total += moon_total
            
            if time_step % print_step == 0:
                pot_str = "{:3} + {:3} + {:3} = {:3}".format(moon.pos[time_step].x, moon.pos[time_step].y, moon.pos[time_step].z, pot)
                kin_str = "{:3} + {:3} + {:3} = {:3}".format(moon.vel[time_step].x, moon.vel[time_step].y, moon.vel[time_step].z, kin)
                total_str = "{:3} * {:3} = {:4}".format(pot, kin, moon_total)

                if len(moon.name) > 6:
                    print("{}:\t pos={};\t vel={};\t total={}".format(moon.name, pot_str, kin_str, total_str))
                else:
                    print("{}:\t\t pos={};\t vel={};\t total={}".format(moon.name, pot_str, kin_str, total_str))

        if time_step % print_step == 0:
            print("Sum of total energy: {}".format(total))
            
    def timeShift(self, num_steps, print_step):
        '''
        This is the main controlling function that will loop over a given range of steps and make calculations
        '''
        jupiter.getPosition(0)
        for i in range(1, num_steps):
            jupiter.calculateVelocity(i)
            if i % print_step == 0:
                jupiter.getPosition(i)
            jupiter.getEnergy(i, print_step)

# %%
'''
Test 1
'''
moon_list = ["Io", "Europa", "Ganymede", "Callisto"]

test_scan = '''<x=-1, y=0, z=2>
<x=2, y=-10, z=-7>
<x=4, y=-8, z=8>
<x=3, y=5, z=-1>'''

scan = test_scan.split("\n")
jupiter = System(moon_list, scan)

jupiter.timeShift(11, 1)
# Out:
# After 0 steps:
# Io:		 pos=<x= -1, y=  0, z=  2>, 	 vel=<x=  0, y=  0, z=  0>
# Europa:		 pos=<x=  2, y=-10, z= -7>, 	 vel=<x=  0, y=  0, z=  0>
# Ganymede:	 pos=<x=  4, y= -8, z=  8>, 	 vel=<x=  0, y=  0, z=  0>
# Callisto:	 pos=<x=  3, y=  5, z= -1>, 	 vel=<x=  0, y=  0, z=  0>
# After 1 steps:
# Io:		 pos=<x=  2, y= -1, z=  1>, 	 vel=<x=  3, y= -1, z= -1>
# Europa:		 pos=<x=  3, y= -7, z= -4>, 	 vel=<x=  1, y=  3, z=  3>
# Ganymede:	 pos=<x=  1, y= -7, z=  5>, 	 vel=<x= -3, y=  1, z= -3>
# Callisto:	 pos=<x=  2, y=  2, z=  0>, 	 vel=<x= -1, y= -3, z=  1>
# Energy after 1 steps:
# Io:		 pos=  2 +  -1 +   1 =   4;	 vel=  3 +  -1 +  -1 =   5;	 total=  4 *   5 =   20
# Europa:		 pos=  3 +  -7 +  -4 =  14;	 vel=  1 +   3 +   3 =   7;	 total= 14 *   7 =   98
# Ganymede:	 pos=  1 +  -7 +   5 =  13;	 vel= -3 +   1 +  -3 =   7;	 total= 13 *   7 =   91
# Callisto:	 pos=  2 +   2 +   0 =   4;	 vel= -1 +  -3 +   1 =   5;	 total=  4 *   5 =   20
# Sum of total energy: 229
# After 2 steps:
# Io:		 pos=<x=  5, y= -3, z= -1>, 	 vel=<x=  3, y= -2, z= -2>
# Europa:		 pos=<x=  1, y= -2, z=  2>, 	 vel=<x= -2, y=  5, z=  6>
# Ganymede:	 pos=<x=  1, y= -4, z= -1>, 	 vel=<x=  0, y=  3, z= -6>
# Callisto:	 pos=<x=  1, y= -4, z=  2>, 	 vel=<x= -1, y= -6, z=  2>
# Energy after 2 steps:
# Io:		 pos=  5 +  -3 +  -1 =   9;	 vel=  3 +  -2 +  -2 =   7;	 total=  9 *   7 =   63
# Europa:		 pos=  1 +  -2 +   2 =   5;	 vel= -2 +   5 +   6 =  13;	 total=  5 *  13 =   65
# Ganymede:	 pos=  1 +  -4 +  -1 =   6;	 vel=  0 +   3 +  -6 =   9;	 total=  6 *   9 =   54
# Callisto:	 pos=  1 +  -4 +   2 =   7;	 vel= -1 +  -6 +   2 =   9;	 total=  7 *   9 =   63
# Sum of total energy: 245
# After 3 steps:
# Io:		 pos=<x=  5, y= -6, z= -1>, 	 vel=<x=  0, y= -3, z=  0>
# Europa:		 pos=<x=  0, y=  0, z=  6>, 	 vel=<x= -1, y=  2, z=  4>
# Ganymede:	 pos=<x=  2, y=  1, z= -5>, 	 vel=<x=  1, y=  5, z= -4>
# Callisto:	 pos=<x=  1, y= -8, z=  2>, 	 vel=<x=  0, y= -4, z=  0>
# Energy after 3 steps:
# Io:		 pos=  5 +  -6 +  -1 =  12;	 vel=  0 +  -3 +   0 =   3;	 total= 12 *   3 =   36
# Europa:		 pos=  0 +   0 +   6 =   6;	 vel= -1 +   2 +   4 =   7;	 total=  6 *   7 =   42
# Ganymede:	 pos=  2 +   1 +  -5 =   8;	 vel=  1 +   5 +  -4 =  10;	 total=  8 *  10 =   80
# Callisto:	 pos=  1 +  -8 +   2 =  11;	 vel=  0 +  -4 +   0 =   4;	 total= 11 *   4 =   44
# Sum of total energy: 202
# After 4 steps:
# Io:		 pos=<x=  2, y= -8, z=  0>, 	 vel=<x= -3, y= -2, z=  1>
# Europa:		 pos=<x=  2, y=  1, z=  7>, 	 vel=<x=  2, y=  1, z=  1>
# Ganymede:	 pos=<x=  2, y=  3, z= -6>, 	 vel=<x=  0, y=  2, z= -1>
# Callisto:	 pos=<x=  2, y= -9, z=  1>, 	 vel=<x=  1, y= -1, z= -1>
# Energy after 4 steps:
# Io:		 pos=  2 +  -8 +   0 =  10;	 vel= -3 +  -2 +   1 =   6;	 total= 10 *   6 =   60
# Europa:		 pos=  2 +   1 +   7 =  10;	 vel=  2 +   1 +   1 =   4;	 total= 10 *   4 =   40
# Ganymede:	 pos=  2 +   3 +  -6 =  11;	 vel=  0 +   2 +  -1 =   3;	 total= 11 *   3 =   33
# Callisto:	 pos=  2 +  -9 +   1 =  12;	 vel=  1 +  -1 +  -1 =   3;	 total= 12 *   3 =   36
# Sum of total energy: 169
# After 5 steps:
# Io:		 pos=<x= -1, y= -9, z=  2>, 	 vel=<x= -3, y= -1, z=  2>
# Europa:		 pos=<x=  4, y=  1, z=  5>, 	 vel=<x=  2, y=  0, z= -2>
# Ganymede:	 pos=<x=  2, y=  2, z= -4>, 	 vel=<x=  0, y= -1, z=  2>
# Callisto:	 pos=<x=  3, y= -7, z= -1>, 	 vel=<x=  1, y=  2, z= -2>
# Energy after 5 steps:
# Io:		 pos= -1 +  -9 +   2 =  12;	 vel= -3 +  -1 +   2 =   6;	 total= 12 *   6 =   72
# Europa:		 pos=  4 +   1 +   5 =  10;	 vel=  2 +   0 +  -2 =   4;	 total= 10 *   4 =   40
# Ganymede:	 pos=  2 +   2 +  -4 =   8;	 vel=  0 +  -1 +   2 =   3;	 total=  8 *   3 =   24
# Callisto:	 pos=  3 +  -7 +  -1 =  11;	 vel=  1 +   2 +  -2 =   5;	 total= 11 *   5 =   55
# Sum of total energy: 191
# After 6 steps:
# Io:		 pos=<x= -1, y= -7, z=  3>, 	 vel=<x=  0, y=  2, z=  1>
# Europa:		 pos=<x=  3, y=  0, z=  0>, 	 vel=<x= -1, y= -1, z= -5>
# Ganymede:	 pos=<x=  3, y= -2, z=  1>, 	 vel=<x=  1, y= -4, z=  5>
# Callisto:	 pos=<x=  3, y= -4, z= -2>, 	 vel=<x=  0, y=  3, z= -1>
# Energy after 6 steps:
# Io:		 pos= -1 +  -7 +   3 =  11;	 vel=  0 +   2 +   1 =   3;	 total= 11 *   3 =   33
# Europa:		 pos=  3 +   0 +   0 =   3;	 vel= -1 +  -1 +  -5 =   7;	 total=  3 *   7 =   21
# Ganymede:	 pos=  3 +  -2 +   1 =   6;	 vel=  1 +  -4 +   5 =  10;	 total=  6 *  10 =   60
# Callisto:	 pos=  3 +  -4 +  -2 =   9;	 vel=  0 +   3 +  -1 =   4;	 total=  9 *   4 =   36
# Sum of total energy: 150
# After 7 steps:
# Io:		 pos=<x=  2, y= -2, z=  1>, 	 vel=<x=  3, y=  5, z= -2>
# Europa:		 pos=<x=  1, y= -4, z= -4>, 	 vel=<x= -2, y= -4, z= -4>
# Ganymede:	 pos=<x=  3, y= -7, z=  5>, 	 vel=<x=  0, y= -5, z=  4>
# Callisto:	 pos=<x=  2, y=  0, z=  0>, 	 vel=<x= -1, y=  4, z=  2>
# Energy after 7 steps:
# Io:		 pos=  2 +  -2 +   1 =   5;	 vel=  3 +   5 +  -2 =  10;	 total=  5 *  10 =   50
# Europa:		 pos=  1 +  -4 +  -4 =   9;	 vel= -2 +  -4 +  -4 =  10;	 total=  9 *  10 =   90
# Ganymede:	 pos=  3 +  -7 +   5 =  15;	 vel=  0 +  -5 +   4 =   9;	 total= 15 *   9 =  135
# Callisto:	 pos=  2 +   0 +   0 =   2;	 vel= -1 +   4 +   2 =   7;	 total=  2 *   7 =   14
# Sum of total energy: 289
# After 8 steps:
# Io:		 pos=<x=  5, y=  2, z= -2>, 	 vel=<x=  3, y=  4, z= -3>
# Europa:		 pos=<x=  2, y= -7, z= -5>, 	 vel=<x=  1, y= -3, z= -1>
# Ganymede:	 pos=<x=  0, y= -9, z=  6>, 	 vel=<x= -3, y= -2, z=  1>
# Callisto:	 pos=<x=  1, y=  1, z=  3>, 	 vel=<x= -1, y=  1, z=  3>
# Energy after 8 steps:
# Io:		 pos=  5 +   2 +  -2 =   9;	 vel=  3 +   4 +  -3 =  10;	 total=  9 *  10 =   90
# Europa:		 pos=  2 +  -7 +  -5 =  14;	 vel=  1 +  -3 +  -1 =   5;	 total= 14 *   5 =   70
# Ganymede:	 pos=  0 +  -9 +   6 =  15;	 vel= -3 +  -2 +   1 =   6;	 total= 15 *   6 =   90
# Callisto:	 pos=  1 +   1 +   3 =   5;	 vel= -1 +   1 +   3 =   5;	 total=  5 *   5 =   25
# Sum of total energy: 275
# After 9 steps:
# Io:		 pos=<x=  5, y=  3, z= -4>, 	 vel=<x=  0, y=  1, z= -2>
# Europa:		 pos=<x=  2, y= -9, z= -3>, 	 vel=<x=  0, y= -2, z=  2>
# Ganymede:	 pos=<x=  0, y= -8, z=  4>, 	 vel=<x=  0, y=  1, z= -2>
# Callisto:	 pos=<x=  1, y=  1, z=  5>, 	 vel=<x=  0, y=  0, z=  2>
# Energy after 9 steps:
# Io:		 pos=  5 +   3 +  -4 =  12;	 vel=  0 +   1 +  -2 =   3;	 total= 12 *   3 =   36
# Europa:		 pos=  2 +  -9 +  -3 =  14;	 vel=  0 +  -2 +   2 =   4;	 total= 14 *   4 =   56
# Ganymede:	 pos=  0 +  -8 +   4 =  12;	 vel=  0 +   1 +  -2 =   3;	 total= 12 *   3 =   36
# Callisto:	 pos=  1 +   1 +   5 =   7;	 vel=  0 +   0 +   2 =   2;	 total=  7 *   2 =   14
# Sum of total energy: 142
# After 10 steps:
# Io:		 pos=<x=  2, y=  1, z= -3>, 	 vel=<x= -3, y= -2, z=  1>
# Europa:		 pos=<x=  1, y= -8, z=  0>, 	 vel=<x= -1, y=  1, z=  3>
# Ganymede:	 pos=<x=  3, y= -6, z=  1>, 	 vel=<x=  3, y=  2, z= -3>
# Callisto:	 pos=<x=  2, y=  0, z=  4>, 	 vel=<x=  1, y= -1, z= -1>
# Energy after 10 steps:
# Io:		 pos=  2 +   1 +  -3 =   6;	 vel= -3 +  -2 +   1 =   6;	 total=  6 *   6 =   36
# Europa:		 pos=  1 +  -8 +   0 =   9;	 vel= -1 +   1 +   3 =   5;	 total=  9 *   5 =   45
# Ganymede:	 pos=  3 +  -6 +   1 =  10;	 vel=  3 +   2 +  -3 =   8;	 total= 10 *   8 =   80
# Callisto:	 pos=  2 +   0 +   4 =   6;	 vel=  1 +  -1 +  -1 =   3;	 total=  6 *   3 =   18
# Sum of total energy: 179

# %%
'''
Test 2
'''
test_scan = '''<x=-8, y=-10, z=0>
<x=5, y=5, z=10>
<x=2, y=-7, z=3>
<x=9, y=-8, z=-3>'''

scan = test_scan.split("\n")
jupiter = System(moon_list, scan)

jupiter.timeShift(101, 10)
# Out:
# After 0 steps:
# Io:		 pos=<x= -8, y=-10, z=  0>, 	 vel=<x=  0, y=  0, z=  0>
# Europa:		 pos=<x=  5, y=  5, z= 10>, 	 vel=<x=  0, y=  0, z=  0>
# Ganymede:	 pos=<x=  2, y= -7, z=  3>, 	 vel=<x=  0, y=  0, z=  0>
# Callisto:	 pos=<x=  9, y= -8, z= -3>, 	 vel=<x=  0, y=  0, z=  0>
# After 10 steps:
# Io:		 pos=<x= -9, y=-10, z=  1>, 	 vel=<x= -2, y= -2, z= -1>
# Europa:		 pos=<x=  4, y= 10, z=  9>, 	 vel=<x= -3, y=  7, z= -2>
# Ganymede:	 pos=<x=  8, y=-10, z= -3>, 	 vel=<x=  5, y= -1, z= -2>
# Callisto:	 pos=<x=  5, y=-10, z=  3>, 	 vel=<x=  0, y= -4, z=  5>
# Energy after 10 steps:
# Io:		 pos= -9 + -10 +   1 =  20;	 vel= -2 +  -2 +  -1 =   5;	 total= 20 *   5 =  100
# Europa:		 pos=  4 +  10 +   9 =  23;	 vel= -3 +   7 +  -2 =  12;	 total= 23 *  12 =  276
# Ganymede:	 pos=  8 + -10 +  -3 =  21;	 vel=  5 +  -1 +  -2 =   8;	 total= 21 *   8 =  168
# Callisto:	 pos=  5 + -10 +   3 =  18;	 vel=  0 +  -4 +   5 =   9;	 total= 18 *   9 =  162
# Sum of total energy: 706
# After 20 steps:
# Io:		 pos=<x=-10, y=  3, z= -4>, 	 vel=<x= -5, y=  2, z=  0>
# Europa:		 pos=<x=  5, y=-25, z=  6>, 	 vel=<x=  1, y=  1, z= -4>
# Ganymede:	 pos=<x= 13, y=  1, z=  1>, 	 vel=<x=  5, y= -2, z=  2>
# Callisto:	 pos=<x=  0, y=  1, z=  7>, 	 vel=<x= -1, y= -1, z=  2>
# Energy after 20 steps:
# Io:		 pos=-10 +   3 +  -4 =  17;	 vel= -5 +   2 +   0 =   7;	 total= 17 *   7 =  119
# Europa:		 pos=  5 + -25 +   6 =  36;	 vel=  1 +   1 +  -4 =   6;	 total= 36 *   6 =  216
# Ganymede:	 pos= 13 +   1 +   1 =  15;	 vel=  5 +  -2 +   2 =   9;	 total= 15 *   9 =  135
# Callisto:	 pos=  0 +   1 +   7 =   8;	 vel= -1 +  -1 +   2 =   4;	 total=  8 *   4 =   32
# Sum of total energy: 502
# After 30 steps:
# Io:		 pos=<x= 15, y= -6, z= -9>, 	 vel=<x= -5, y=  4, z=  0>
# Europa:		 pos=<x= -4, y=-11, z=  3>, 	 vel=<x= -3, y=-10, z=  0>
# Ganymede:	 pos=<x=  0, y= -1, z= 11>, 	 vel=<x=  7, y=  4, z=  3>
# Callisto:	 pos=<x= -3, y= -2, z=  5>, 	 vel=<x=  1, y=  2, z= -3>
# Energy after 30 steps:
# Io:		 pos= 15 +  -6 +  -9 =  30;	 vel= -5 +   4 +   0 =   9;	 total= 30 *   9 =  270
# Europa:		 pos= -4 + -11 +   3 =  18;	 vel= -3 + -10 +   0 =  13;	 total= 18 *  13 =  234
# Ganymede:	 pos=  0 +  -1 +  11 =  12;	 vel=  7 +   4 +   3 =  14;	 total= 12 *  14 =  168
# Callisto:	 pos= -3 +  -2 +   5 =  10;	 vel=  1 +   2 +  -3 =   6;	 total= 10 *   6 =   60
# Sum of total energy: 732
# After 40 steps:
# Io:		 pos=<x= 14, y=-12, z= -4>, 	 vel=<x= 11, y=  3, z=  0>
# Europa:		 pos=<x= -1, y= 18, z=  8>, 	 vel=<x= -5, y=  2, z=  3>
# Ganymede:	 pos=<x= -5, y=-14, z=  8>, 	 vel=<x=  1, y= -2, z=  0>
# Callisto:	 pos=<x=  0, y=-12, z= -2>, 	 vel=<x= -7, y= -3, z= -3>
# Energy after 40 steps:
# Io:		 pos= 14 + -12 +  -4 =  30;	 vel= 11 +   3 +   0 =  14;	 total= 30 *  14 =  420
# Europa:		 pos= -1 +  18 +   8 =  27;	 vel= -5 +   2 +   3 =  10;	 total= 27 *  10 =  270
# Ganymede:	 pos= -5 + -14 +   8 =  27;	 vel=  1 +  -2 +   0 =   3;	 total= 27 *   3 =   81
# Callisto:	 pos=  0 + -12 +  -2 =  14;	 vel= -7 +  -3 +  -3 =  13;	 total= 14 *  13 =  182
# Sum of total energy: 953
# After 50 steps:
# Io:		 pos=<x=-23, y=  4, z=  1>, 	 vel=<x= -7, y= -1, z=  2>
# Europa:		 pos=<x= 20, y=-31, z= 13>, 	 vel=<x=  5, y=  3, z=  4>
# Ganymede:	 pos=<x= -4, y=  6, z=  1>, 	 vel=<x= -1, y=  1, z= -3>
# Callisto:	 pos=<x= 15, y=  1, z= -5>, 	 vel=<x=  3, y= -3, z= -3>
# Energy after 50 steps:
# Io:		 pos=-23 +   4 +   1 =  28;	 vel= -7 +  -1 +   2 =  10;	 total= 28 *  10 =  280
# Europa:		 pos= 20 + -31 +  13 =  64;	 vel=  5 +   3 +   4 =  12;	 total= 64 *  12 =  768
# Ganymede:	 pos= -4 +   6 +   1 =  11;	 vel= -1 +   1 +  -3 =   5;	 total= 11 *   5 =   55
# Callisto:	 pos= 15 +   1 +  -5 =  21;	 vel=  3 +  -3 +  -3 =   9;	 total= 21 *   9 =  189
# Sum of total energy: 1292
# After 60 steps:
# Io:		 pos=<x= 36, y=-10, z=  6>, 	 vel=<x=  5, y=  0, z=  3>
# Europa:		 pos=<x=-18, y= 10, z=  9>, 	 vel=<x= -3, y= -7, z=  5>
# Ganymede:	 pos=<x=  8, y=-12, z= -3>, 	 vel=<x= -2, y=  1, z= -7>
# Callisto:	 pos=<x=-18, y= -8, z= -2>, 	 vel=<x=  0, y=  6, z= -1>
# Energy after 60 steps:
# Io:		 pos= 36 + -10 +   6 =  52;	 vel=  5 +   0 +   3 =   8;	 total= 52 *   8 =  416
# Europa:		 pos=-18 +  10 +   9 =  37;	 vel= -3 +  -7 +   5 =  15;	 total= 37 *  15 =  555
# Ganymede:	 pos=  8 + -12 +  -3 =  23;	 vel= -2 +   1 +  -7 =  10;	 total= 23 *  10 =  230
# Callisto:	 pos=-18 +  -8 +  -2 =  28;	 vel=  0 +   6 +  -1 =   7;	 total= 28 *   7 =  196
# Sum of total energy: 1397
# After 70 steps:
# Io:		 pos=<x=-33, y= -6, z=  5>, 	 vel=<x= -5, y= -4, z=  7>
# Europa:		 pos=<x= 13, y= -9, z=  2>, 	 vel=<x= -2, y= 11, z=  3>
# Ganymede:	 pos=<x= 11, y= -8, z=  2>, 	 vel=<x=  8, y= -6, z= -7>
# Callisto:	 pos=<x= 17, y=  3, z=  1>, 	 vel=<x= -1, y= -1, z= -3>
# Energy after 70 steps:
# Io:		 pos=-33 +  -6 +   5 =  44;	 vel= -5 +  -4 +   7 =  16;	 total= 44 *  16 =  704
# Europa:		 pos= 13 +  -9 +   2 =  24;	 vel= -2 +  11 +   3 =  16;	 total= 24 *  16 =  384
# Ganymede:	 pos= 11 +  -8 +   2 =  21;	 vel=  8 +  -6 +  -7 =  21;	 total= 21 *  21 =  441
# Callisto:	 pos= 17 +   3 +   1 =  21;	 vel= -1 +  -1 +  -3 =   5;	 total= 21 *   5 =  105
# Sum of total energy: 1634
# After 80 steps:
# Io:		 pos=<x= 30, y= -8, z=  3>, 	 vel=<x=  3, y=  3, z=  0>
# Europa:		 pos=<x= -2, y= -4, z=  0>, 	 vel=<x=  4, y=-13, z=  2>
# Ganymede:	 pos=<x=-18, y= -7, z= 15>, 	 vel=<x= -8, y=  2, z= -2>
# Callisto:	 pos=<x= -2, y= -1, z= -8>, 	 vel=<x=  1, y=  8, z=  0>
# Energy after 80 steps:
# Io:		 pos= 30 +  -8 +   3 =  41;	 vel=  3 +   3 +   0 =   6;	 total= 41 *   6 =  246
# Europa:		 pos= -2 +  -4 +   0 =   6;	 vel=  4 + -13 +   2 =  19;	 total=  6 *  19 =  114
# Ganymede:	 pos=-18 +  -7 +  15 =  40;	 vel= -8 +   2 +  -2 =  12;	 total= 40 *  12 =  480
# Callisto:	 pos= -2 +  -1 +  -8 =  11;	 vel=  1 +   8 +   0 =   9;	 total= 11 *   9 =   99
# Sum of total energy: 939
# After 90 steps:
# Io:		 pos=<x=-25, y= -1, z=  4>, 	 vel=<x=  1, y= -3, z=  4>
# Europa:		 pos=<x=  2, y= -9, z=  0>, 	 vel=<x= -3, y= 13, z= -1>
# Ganymede:	 pos=<x= 32, y= -8, z= 14>, 	 vel=<x=  5, y= -4, z=  6>
# Callisto:	 pos=<x= -1, y= -2, z= -8>, 	 vel=<x= -3, y= -6, z= -9>
# Energy after 90 steps:
# Io:		 pos=-25 +  -1 +   4 =  30;	 vel=  1 +  -3 +   4 =   8;	 total= 30 *   8 =  240
# Europa:		 pos=  2 +  -9 +   0 =  11;	 vel= -3 +  13 +  -1 =  17;	 total= 11 *  17 =  187
# Ganymede:	 pos= 32 +  -8 +  14 =  54;	 vel=  5 +  -4 +   6 =  15;	 total= 54 *  15 =  810
# Callisto:	 pos= -1 +  -2 +  -8 =  11;	 vel= -3 +  -6 +  -9 =  18;	 total= 11 *  18 =  198
# Sum of total energy: 1435
# After 100 steps:
# Io:		 pos=<x=  8, y=-12, z= -9>, 	 vel=<x= -7, y=  3, z=  0>
# Europa:		 pos=<x= 13, y= 16, z= -3>, 	 vel=<x=  3, y=-11, z= -5>
# Ganymede:	 pos=<x=-29, y=-11, z= -1>, 	 vel=<x= -3, y=  7, z=  4>
# Callisto:	 pos=<x= 16, y=-13, z= 23>, 	 vel=<x=  7, y=  1, z=  1>
# Energy after 100 steps:
# Io:		 pos=  8 + -12 +  -9 =  29;	 vel= -7 +   3 +   0 =  10;	 total= 29 *  10 =  290
# Europa:		 pos= 13 +  16 +  -3 =  32;	 vel=  3 + -11 +  -5 =  19;	 total= 32 *  19 =  608
# Ganymede:	 pos=-29 + -11 +  -1 =  41;	 vel= -3 +   7 +   4 =  14;	 total= 41 *  14 =  574
# Callisto:	 pos= 16 + -13 +  23 =  52;	 vel=  7 +   1 +   1 =   9;	 total= 52 *   9 =  468
# Sum of total energy: 1940

# %%
'''
Real Run
'''

scan_string = '''<x=0, y=4, z=0>
<x=-10, y=-6, z=-14>
<x=9, y=-16, z=-3>
<x=6, y=-1, z=2>'''

scan = scan_string.split("\n")
jupiter = System(moon_list, scan)

# Because we're doing so many steps, let's only print out every 100 to make sure we're on track.
jupiter.timeShift(1001, 100)
# Out:
# After 0 steps:
# Io:		 pos=<x=  0, y=  4, z=  0>, 	 vel=<x=  0, y=  0, z=  0>
# Europa:		 pos=<x=-10, y= -6, z=-14>, 	 vel=<x=  0, y=  0, z=  0>
# Ganymede:	 pos=<x=  9, y=-16, z= -3>, 	 vel=<x=  0, y=  0, z=  0>
# Callisto:	 pos=<x=  6, y= -1, z=  2>, 	 vel=<x=  0, y=  0, z=  0>
# After 100 steps:
# Io:		 pos=<x= -4, y=  4, z=  5>, 	 vel=<x=  6, y= -4, z=  0>
# Europa:		 pos=<x=-12, y=  1, z=  0>, 	 vel=<x= -8, y=  4, z= -1>
# Ganymede:	 pos=<x=  6, y= -7, z= -2>, 	 vel=<x=  2, y=  3, z=  5>
# Callisto:	 pos=<x= 15, y=-17, z=-18>, 	 vel=<x=  0, y= -3, z= -4>
# Energy after 100 steps:
# Io:		 pos= -4 +   4 +   5 =  13;	 vel=  6 +  -4 +   0 =  10;	 total= 13 *  10 =  130
# Europa:		 pos=-12 +   1 +   0 =  13;	 vel= -8 +   4 +  -1 =  13;	 total= 13 *  13 =  169
# Ganymede:	 pos=  6 +  -7 +  -2 =  15;	 vel=  2 +   3 +   5 =  10;	 total= 15 *  10 =  150
# Callisto:	 pos= 15 + -17 + -18 =  50;	 vel=  0 +  -3 +  -4 =   7;	 total= 50 *   7 =  350
# Sum of total energy: 799
# After 200 steps:
# Io:		 pos=<x=  9, y=  5, z= -7>, 	 vel=<x= 11, y=  4, z= -2>
# Europa:		 pos=<x=-16, y= -5, z= -5>, 	 vel=<x=  0, y= -3, z=  7>
# Ganymede:	 pos=<x= 11, y= -8, z= -7>, 	 vel=<x= -7, y=  8, z= -5>
# Callisto:	 pos=<x=  1, y=-11, z=  4>, 	 vel=<x= -4, y= -9, z=  0>
# Energy after 200 steps:
# Io:		 pos=  9 +   5 +  -7 =  21;	 vel= 11 +   4 +  -2 =  17;	 total= 21 *  17 =  357
# Europa:		 pos=-16 +  -5 +  -5 =  26;	 vel=  0 +  -3 +   7 =  10;	 total= 26 *  10 =  260
# Ganymede:	 pos= 11 +  -8 +  -7 =  26;	 vel= -7 +   8 +  -5 =  20;	 total= 26 *  20 =  520
# Callisto:	 pos=  1 + -11 +   4 =  16;	 vel= -4 +  -9 +   0 =  13;	 total= 16 *  13 =  208
# Sum of total energy: 1345
# After 300 steps:
# Io:		 pos=<x= 26, y= 33, z=  4>, 	 vel=<x= -1, y= -4, z=  4>
# Europa:		 pos=<x= 28, y=  4, z= -9>, 	 vel=<x=  9, y=  1, z= -1>
# Ganymede:	 pos=<x=-26, y=-30, z= 15>, 	 vel=<x= -4, y=  8, z=  5>
# Callisto:	 pos=<x=-23, y=-26, z=-25>, 	 vel=<x= -4, y= -5, z= -8>
# Energy after 300 steps:
# Io:		 pos= 26 +  33 +   4 =  63;	 vel= -1 +  -4 +   4 =   9;	 total= 63 *   9 =  567
# Europa:		 pos= 28 +   4 +  -9 =  41;	 vel=  9 +   1 +  -1 =  11;	 total= 41 *  11 =  451
# Ganymede:	 pos=-26 + -30 +  15 =  71;	 vel= -4 +   8 +   5 =  17;	 total= 71 *  17 = 1207
# Callisto:	 pos=-23 + -26 + -25 =  74;	 vel= -4 +  -5 +  -8 =  17;	 total= 74 *  17 = 1258
# Sum of total energy: 3483
# After 400 steps:
# Io:		 pos=<x=-20, y=-11, z=  5>, 	 vel=<x=  3, y= 12, z= -4>
# Europa:		 pos=<x=  4, y=-17, z=-28>, 	 vel=<x=-16, y=  0, z=  5>
# Ganymede:	 pos=<x=  8, y=-16, z= -6>, 	 vel=<x=  7, y=-16, z= -5>
# Callisto:	 pos=<x= 13, y= 25, z= 14>, 	 vel=<x=  6, y=  4, z=  4>
# Energy after 400 steps:
# Io:		 pos=-20 + -11 +   5 =  36;	 vel=  3 +  12 +  -4 =  19;	 total= 36 *  19 =  684
# Europa:		 pos=  4 + -17 + -28 =  49;	 vel=-16 +   0 +   5 =  21;	 total= 49 *  21 = 1029
# Ganymede:	 pos=  8 + -16 +  -6 =  30;	 vel=  7 + -16 +  -5 =  28;	 total= 30 *  28 =  840
# Callisto:	 pos= 13 +  25 +  14 =  52;	 vel=  6 +   4 +   4 =  14;	 total= 52 *  14 =  728
# Sum of total energy: 3281
# After 500 steps:
# Io:		 pos=<x= -5, y= -8, z= -2>, 	 vel=<x=  8, y=-12, z= -3>
# Europa:		 pos=<x= 70, y= 27, z= 15>, 	 vel=<x= -5, y= -4, z= -4>
# Ganymede:	 pos=<x=-34, y=-10, z=-30>, 	 vel=<x= -6, y=  7, z= -9>
# Callisto:	 pos=<x=-26, y=-28, z=  2>, 	 vel=<x=  3, y=  9, z= 16>
# Energy after 500 steps:
# Io:		 pos= -5 +  -8 +  -2 =  15;	 vel=  8 + -12 +  -3 =  23;	 total= 15 *  23 =  345
# Europa:		 pos= 70 +  27 +  15 = 112;	 vel= -5 +  -4 +  -4 =  13;	 total=112 *  13 = 1456
# Ganymede:	 pos=-34 + -10 + -30 =  74;	 vel= -6 +   7 +  -9 =  22;	 total= 74 *  22 = 1628
# Callisto:	 pos=-26 + -28 +   2 =  56;	 vel=  3 +   9 +  16 =  28;	 total= 56 *  28 = 1568
# Sum of total energy: 4997
# After 600 steps:
# Io:		 pos=<x= 12, y=-22, z=  3>, 	 vel=<x= -4, y=-18, z=-13>
# Europa:		 pos=<x=-67, y=  8, z= 39>, 	 vel=<x=-19, y= -3, z=  4>
# Ganymede:	 pos=<x= 39, y= 24, z=-57>, 	 vel=<x= 11, y=  9, z=  7>
# Callisto:	 pos=<x= 21, y=-29, z=  0>, 	 vel=<x= 12, y= 12, z=  2>
# Energy after 600 steps:
# Io:		 pos= 12 + -22 +   3 =  37;	 vel= -4 + -18 + -13 =  35;	 total= 37 *  35 = 1295
# Europa:		 pos=-67 +   8 +  39 = 114;	 vel=-19 +  -3 +   4 =  26;	 total=114 *  26 = 2964
# Ganymede:	 pos= 39 +  24 + -57 = 120;	 vel= 11 +   9 +   7 =  27;	 total=120 *  27 = 3240
# Callisto:	 pos= 21 + -29 +   0 =  50;	 vel= 12 +  12 +   2 =  26;	 total= 50 *  26 = 1300
# Sum of total energy: 8799
# After 700 steps:
# Io:		 pos=<x=-44, y= 72, z= -9>, 	 vel=<x= -8, y=  0, z= -2>
# Europa:		 pos=<x=155, y=-10, z=-13>, 	 vel=<x=  9, y=-13, z=  5>
# Ganymede:	 pos=<x=-27, y=-60, z=-49>, 	 vel=<x=  1, y= 13, z= -7>
# Callisto:	 pos=<x=-79, y=-21, z= 56>, 	 vel=<x= -2, y=  0, z=  4>
# Energy after 700 steps:
# Io:		 pos=-44 +  72 +  -9 = 125;	 vel= -8 +   0 +  -2 =  10;	 total=125 *  10 = 1250
# Europa:		 pos=155 + -10 + -13 = 178;	 vel=  9 + -13 +   5 =  27;	 total=178 *  27 = 4806
# Ganymede:	 pos=-27 + -60 + -49 = 136;	 vel=  1 +  13 +  -7 =  21;	 total=136 *  21 = 2856
# Callisto:	 pos=-79 + -21 +  56 = 156;	 vel= -2 +   0 +   4 =   6;	 total=156 *   6 =  936
# Sum of total energy: 9848
# After 800 steps:
# Io:		 pos=<x= 52, y=-40, z= -8>, 	 vel=<x=  2, y= -2, z= -2>
# Europa:		 pos=<x=-107, y= 50, z= 33>, 	 vel=<x=-19, y= -2, z=  7>
# Ganymede:	 pos=<x= 51, y= -6, z=-47>, 	 vel=<x= 11, y=-14, z=-13>
# Callisto:	 pos=<x=  9, y=-23, z=  7>, 	 vel=<x=  6, y= 18, z=  8>
# Energy after 800 steps:
# Io:		 pos= 52 + -40 +  -8 = 100;	 vel=  2 +  -2 +  -2 =   6;	 total=100 *   6 =  600
# Europa:		 pos=-107 +  50 +  33 = 190;	 vel=-19 +  -2 +   7 =  28;	 total=190 *  28 = 5320
# Ganymede:	 pos= 51 +  -6 + -47 = 104;	 vel= 11 + -14 + -13 =  38;	 total=104 *  38 = 3952
# Callisto:	 pos=  9 + -23 +   7 =  39;	 vel=  6 +  18 +   8 =  32;	 total= 39 *  32 = 1248
# Sum of total energy: 11120
# After 900 steps:
# Io:		 pos=<x=-12, y=-26, z= 46>, 	 vel=<x= -6, y=-11, z=  6>
# Europa:		 pos=<x= 37, y=-72, z=-73>, 	 vel=<x= 29, y=  4, z=  1>
# Ganymede:	 pos=<x=-43, y= 66, z=  1>, 	 vel=<x=-10, y=  9, z= -1>
# Callisto:	 pos=<x= 23, y= 13, z= 11>, 	 vel=<x=-13, y= -2, z= -6>
# Energy after 900 steps:
# Io:		 pos=-12 + -26 +  46 =  84;	 vel= -6 + -11 +   6 =  23;	 total= 84 *  23 = 1932
# Europa:		 pos= 37 + -72 + -73 = 182;	 vel= 29 +   4 +   1 =  34;	 total=182 *  34 = 6188
# Ganymede:	 pos=-43 +  66 +   1 = 110;	 vel=-10 +   9 +  -1 =  20;	 total=110 *  20 = 2200
# Callisto:	 pos= 23 +  13 +  11 =  47;	 vel=-13 +  -2 +  -6 =  21;	 total= 47 *  21 =  987
# Sum of total energy: 11307
# After 1000 steps:
# Io:		 pos=<x=-16, y= 79, z=-15>, 	 vel=<x=  9, y=  0, z=  1>
# Europa:		 pos=<x=124, y=-44, z= 39>, 	 vel=<x=-16, y=-16, z=-12>
# Ganymede:	 pos=<x=-57, y=-47, z= -4>, 	 vel=<x=  2, y=  7, z=  6>
# Callisto:	 pos=<x=-46, y= -7, z=-35>, 	 vel=<x=  5, y=  9, z=  5>
# Energy after 1000 steps:
# Io:		 pos=-16 +  79 + -15 = 110;	 vel=  9 +   0 +   1 =  10;	 total=110 *  10 = 1100
# Europa:		 pos=124 + -44 +  39 = 207;	 vel=-16 + -16 + -12 =  44;	 total=207 *  44 = 9108
# Ganymede:	 pos=-57 + -47 +  -4 = 108;	 vel=  2 +   7 +   6 =  15;	 total=108 *  15 = 1620
# Callisto:	 pos=-46 +  -7 + -35 =  88;	 vel=  5 +   9 +   5 =  19;	 total= 88 *  19 = 1672
# Sum of total energy: 13500
