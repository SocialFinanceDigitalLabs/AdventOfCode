# %%
import operator
import math

# %%
class Asteroid:
    '''
    Treat each asteroid as an object so we can
    store its coordinates and status centrally
    '''
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.status = True
        self.slope = False
        self.destroyed = False
        self.destroyed_order = -1
        
    def calculateSlope(self, mon):
        '''
        Calculating the slope in radians so we can determine
        which ones to hit.
        '''
        try:
            self.slope = math.atan2(mon.y - self.y, mon.x - self.x)
            #self.slope = ((mon.y - self.y) / (mon.x - self.x))
        except ZeroDivisionError:
            self.slope = "Infinite"
            
        # We need to adjust things so we sweep based on the order the puzzle wants
        # We want to go from pi/2 to pi
        # then -pi to 0, and then 0 to pi/2
        # There's probably a different way to do this that is easier, but...let's rotate the points' slopes
        if self.slope >= math.pi / 2 and self.slope <= math.pi:
            # Move this towards zero as they are first
            self.slope = self.slope - (math.pi / 2)
        elif self.slope >= -math.pi and self.slope <= math.pi / 2:
            # Make these much larger as they should happen after the first points.
            self.slope = self.slope + (math.pi * 2)
    
    def printPoint(self):
        return "({},{})".format(self.x, self.y)
            
        
            

class Monitor:
    '''
    The entire system we're checking
    '''
    def __init__(self, amap):
        print("[-] Setting up...")
        self.text_map = amap
        self.asteroid_map = self.processMap()
        self.mon = False
        self.mon_count = 0
        
    def calculateAsteroidSlopes(self):
        '''
        To do the sweeping motion, we need to get the radians of each
        point as it relates to the monitoring point.
        Our sweep will begin at 0, go to pi, flip negative, and go 
        back down to zero again.
        '''
        print("[-] Finding slopes to asteroids...")
        for item in self.asteroid_map:
            if self.isSame(item, self.mon):
                continue
            else:
                item.calculateSlope(self.mon)
                
        self.asteroid_map.sort(key=lambda x: x.slope)
                
    def printSlopes(self):
        '''
        A simple output function to throw out the slopes we found...
        '''
        for item in self.asteroid_map:
            if self.isSame(item, self.mon):
                continue
            else:
                print("({},{}) = {}".format(item.x, item.y, item.slope))
        
        
    def findBestMonitorLocation(self):
        '''
        This function finds the best monitor location.
        Was outside the class object last time in part 1...
        '''
        print("[-] Processing...")
        result = mon.testViewPoints()
        for item in result:
            if result[item]["count"] > self.mon_count:
                self.mon_count = result[item]["count"]
                self.mon = result[item]["point"]
        
        print("Monitor set at position ({},{})".format(self.mon.x, self.mon.y))
        self.calculateAsteroidSlopes()
        
    def processMap(self):
        '''
        This takes the string map given to us
        and turns it into something we can use
        '''
        asteroids = list()
        listmap = self.text_map.split('\n')
        
        for ridx, row in enumerate(listmap):
            for cidx, col in enumerate(row):
                if col == '#':
                    # Astroid found, create point and add to list
                    asteroids.append(Asteroid(cidx, ridx))
        return asteroids
    
    def checkView(self, mon_point):
        '''
        This looks over all the asteroids, and checks to see which
        ones are visible given the mon_point we're testing
        '''
        for end_point in self.asteroid_map:
            if end_point.destroyed is True:
                continue
            for mid_point in self.asteroid_map:
                if mid_point.destroyed is True:
                    continue
                elif self.isSame(end_point, mid_point) or self.isSame(mon_point, mid_point):
                    continue
                elif self.isOn(mon_point, end_point, mid_point):
                    end_point.status = False
    
    def resetView(self):
        '''
        After we check a monitoring point, we want to reset the view
        back to the original, ready for the next test
        '''
        for point in self.asteroid_map:
            point.status = True
    
    def countViewablePoints(self, mon_point):
        '''
        After the tests are done, count up the asteroids that are viewable
        '''
        count = 0
        self.checkView(mon_point)
        for point in self.asteroid_map:
            if not self.isSame(mon_point, point) and point.status is True:
                count += 1
        return count
    
    def testViewPoints(self):
        '''
        Main function tying things together and returning the result to the user
        '''
        result = dict()
        for mon_point in self.asteroid_map:
            count = self.countViewablePoints(mon_point)
            thiskey = "({},{})".format(mon_point.x, mon_point.y)
            result[thiskey] = {
                "count": count,
                "point": mon_point
            }
            self.resetView()
            
        
        return result
    
    def isSame(self, a, b):
        '''
        This function is used to try to avoid typing this same thing over
        and over. We don't want to check if a monitor can see itself!
        '''
        if a.x == b.x and a.y == b.y:
            return True
        else:
            return False
    
    
    # Point functions taken from here: https://stackoverflow.com/questions/328107/how-can-you-determine-a-point-is-between-two-other-points-on-a-line-segment 
    def isOn(self, a, b, c):
        '''
        Return true iff point c intersects the line segment from a to b.
        '''
        # (or the degenerate case that all 3 points are coincident)
        return (self.collinear(a, b, c)
                and (self.within(a.x, c.x, b.x) if a.x != b.x else 
                     self.within(a.y, c.y, b.y)))

    def collinear(self, a, b, c):
        '''
        Return true iff a, b, and c all lie on the same line.
        '''
        return (b.x - a.x) * (c.y - a.y) == (c.x - a.x) * (b.y - a.y)

    def within(self, p, q, r):
        '''
        Return true iff q is between p and r (inclusive).
        '''
        return p <= q <= r or r <= q <= p
    
    def laserSweep(self, target_count):
        '''
            We want to only hit asteroids that are visible at this monitoring point
            Reset view
            laser again.
            On top of this, we need to count the asteroids as they're being destroyed 
            so we know which one
        '''
        print("[-] Destroying!")
        # Resetting view to be that of the monitor's so we know which ones are visible
        self.checkView(self.mon)
        
        sweep_count = 0
        hit_count = 0
        
        while hit_count < len(self.asteroid_map) - 1:
            for item in self.asteroid_map:
                if item.status is True and item.destroyed is False:
                    print("{} is #{} Destroyed!".format(item.printPoint(), hit_count+1))
                    item.destroyed = True
                    item.destroyed_order = hit_count
                    hit_count += 1
                    if hit_count+1 == target_count:
                        print("***** ---> Target Destroyed!!! <--- *****")
            sweep_count += 1
            print("Sweep #{} Done. ({}/{} Hits) ".format(sweep_count, hit_count, len(self.asteroid_map)-1))
            self.resetView()
            self.checkView(self.mon)

# %%
test_map = '''.#....#####...#..
##...##.#####..##
##...#...#.#####.
..#.....#...###..
..#.#.....#....##'''
mon = Monitor(test_map)
mon.findBestMonitorLocation()
mon.calculateAsteroidSlopes()
mon.laserSweep(30)
# Out:
# [-] Setting up...
# [-] Processing...
# Monitor set at position (8,3)
# [-] Finding slopes to asteroids...
# [-] Finding slopes to asteroids...
# [-] Destroying!
# (8,1) is #1 Destroyed!
# (9,0) is #2 Destroyed!
# (9,1) is #3 Destroyed!
# (10,0) is #4 Destroyed!
# (9,2) is #5 Destroyed!
# (11,1) is #6 Destroyed!
# (12,1) is #7 Destroyed!
# (11,2) is #8 Destroyed!
# (15,1) is #9 Destroyed!
# (12,2) is #10 Destroyed!
# (13,2) is #11 Destroyed!
# (14,2) is #12 Destroyed!
# (15,2) is #13 Destroyed!
# (12,3) is #14 Destroyed!
# (16,4) is #15 Destroyed!
# (15,4) is #16 Destroyed!
# (10,4) is #17 Destroyed!
# (4,4) is #18 Destroyed!
# (2,4) is #19 Destroyed!
# (2,3) is #20 Destroyed!
# (0,2) is #21 Destroyed!
# (1,2) is #22 Destroyed!
# (0,1) is #23 Destroyed!
# (1,1) is #24 Destroyed!
# (5,2) is #25 Destroyed!
# (1,0) is #26 Destroyed!
# (5,1) is #27 Destroyed!
# (6,1) is #28 Destroyed!
# (6,0) is #29 Destroyed!
# ***** ---> Target Destroyed!!! <--- *****
# (7,0) is #30 Destroyed!
# Sweep #1 Done. (30/36 Hits)
# (8,0) is #31 Destroyed!
# (10,1) is #32 Destroyed!
# (14,0) is #33 Destroyed!
# (16,1) is #34 Destroyed!
# (13,3) is #35 Destroyed!
# Sweep #2 Done. (35/36 Hits)
# (14,3) is #36 Destroyed!
# Sweep #3 Done. (36/36 Hits)

# %%
with open('Day10-input.txt') as mapfile:
    real_map = mapfile.read()
mon = Monitor(real_map)
mon.findBestMonitorLocation()
mon.calculateAsteroidSlopes()
mon.laserSweep(200)
# Out:
# [-] Setting up...
# [-] Processing...
# Monitor set at position (20,21)
# [-] Finding slopes to asteroids...
# [-] Finding slopes to asteroids...
# [-] Destroying!
# (20,18) is #1 Destroyed!
# (21,1) is #2 Destroyed!
# (21,3) is #3 Destroyed!
# (21,4) is #4 Destroyed!
# (21,5) is #5 Destroyed!
# (21,7) is #6 Destroyed!
# (21,9) is #7 Destroyed!
# (21,11) is #8 Destroyed!
# (22,3) is #9 Destroyed!
# (21,13) is #10 Destroyed!
# (21,14) is #11 Destroyed!
# (23,1) is #12 Destroyed!
# (22,8) is #13 Destroyed!
# (23,2) is #14 Destroyed!
# (21,15) is #15 Destroyed!
# (23,5) is #16 Destroyed!
# (21,16) is #17 Destroyed!
# (23,7) is #18 Destroyed!
# (22,12) is #19 Destroyed!
# (23,9) is #20 Destroyed!
# (23,11) is #21 Destroyed!
# (22,15) is #22 Destroyed!
# (23,14) is #23 Destroyed!
# (21,19) is #24 Destroyed!
# (23,16) is #25 Destroyed!
# (22,18) is #26 Destroyed!
# (23,17) is #27 Destroyed!
# (22,19) is #28 Destroyed!
# (22,20) is #29 Destroyed!
# (21,21) is #30 Destroyed!
# (23,22) is #31 Destroyed!
# (22,22) is #32 Destroyed!
# (23,23) is #33 Destroyed!
# (22,23) is #34 Destroyed!
# (20,23) is #35 Destroyed!
# (19,23) is #36 Destroyed!
# (17,23) is #37 Destroyed!
# (15,23) is #38 Destroyed!
# (17,22) is #39 Destroyed!
# (13,23) is #40 Destroyed!
# (12,23) is #41 Destroyed!
# (11,23) is #42 Destroyed!
# (15,22) is #43 Destroyed!
# (9,23) is #44 Destroyed!
# (7,23) is #45 Destroyed!
# (13,22) is #46 Destroyed!
# (5,23) is #47 Destroyed!
# (4,23) is #48 Destroyed!
# (3,23) is #49 Destroyed!
# (11,22) is #50 Destroyed!
# (1,23) is #51 Destroyed!
# (10,22) is #52 Destroyed!
# (9,22) is #53 Destroyed!
# (7,22) is #54 Destroyed!
# (6,22) is #55 Destroyed!
# (5,22) is #56 Destroyed!
# (2,22) is #57 Destroyed!
# (1,22) is #58 Destroyed!
# (0,22) is #59 Destroyed!
# (19,21) is #60 Destroyed!
# (0,20) is #61 Destroyed!
# (1,20) is #62 Destroyed!
# (2,20) is #63 Destroyed!
# (3,20) is #64 Destroyed!
# (6,20) is #65 Destroyed!
# (9,20) is #66 Destroyed!
# (10,20) is #67 Destroyed!
# (1,19) is #68 Destroyed!
# (3,19) is #69 Destroyed!
# (12,20) is #70 Destroyed!
# (5,19) is #71 Destroyed!
# (6,19) is #72 Destroyed!
# (14,20) is #73 Destroyed!
# (3,18) is #74 Destroyed!
# (4,18) is #75 Destroyed!
# (10,19) is #76 Destroyed!
# (11,19) is #77 Destroyed!
# (7,18) is #78 Destroyed!
# (3,17) is #79 Destroyed!
# (8,18) is #80 Destroyed!
# (1,16) is #81 Destroyed!
# (5,17) is #82 Destroyed!
# (9,18) is #83 Destroyed!
# (2,16) is #84 Destroyed!
# (7,17) is #85 Destroyed!
# (1,15) is #86 Destroyed!
# (8,17) is #87 Destroyed!
# (0,14) is #88 Destroyed!
# (6,16) is #89 Destroyed!
# (9,17) is #90 Destroyed!
# (1,14) is #91 Destroyed!
# (12,18) is #92 Destroyed!
# (7,16) is #93 Destroyed!
# (2,14) is #94 Destroyed!
# (10,17) is #95 Destroyed!
# (3,14) is #96 Destroyed!
# (8,16) is #97 Destroyed!
# (11,17) is #98 Destroyed!
# (0,12) is #99 Destroyed!
# (9,16) is #100 Destroyed!
# (5,14) is #101 Destroyed!
# (1,12) is #102 Destroyed!
# (16,19) is #103 Destroyed!
# (3,12) is #104 Destroyed!
# (5,13) is #105 Destroyed!
# (9,15) is #106 Destroyed!
# (0,10) is #107 Destroyed!
# (11,16) is #108 Destroyed!
# (4,12) is #109 Destroyed!
# (1,10) is #110 Destroyed!
# (8,14) is #111 Destroyed!
# (15,18) is #112 Destroyed!
# (7,13) is #113 Destroyed!
# (12,16) is #114 Destroyed!
# (1,9) is #115 Destroyed!
# (6,12) is #116 Destroyed!
# (3,10) is #117 Destroyed!
# (0,8) is #118 Destroyed!
# (17,19) is #119 Destroyed!
# (1,8) is #120 Destroyed!
# (4,10) is #121 Destroyed!
# (7,12) is #122 Destroyed!
# (10,14) is #123 Destroyed!
# (3,9) is #124 Destroyed!
# (13,16) is #125 Destroyed!
# (2,8) is #126 Destroyed!
# (5,10) is #127 Destroyed!
# (1,7) is #128 Destroyed!
# (16,18) is #129 Destroyed!
# (3,8) is #130 Destroyed!
# (2,7) is #131 Destroyed!
# (1,6) is #132 Destroyed!
# (15,17) is #133 Destroyed!
# (4,8) is #134 Destroyed!
# (9,12) is #135 Destroyed!
# (2,6) is #136 Destroyed!
# (1,5) is #137 Destroyed!
# (7,10) is #138 Destroyed!
# (13,15) is #139 Destroyed!
# (5,8) is #140 Destroyed!
# (12,14) is #141 Destroyed!
# (3,6) is #142 Destroyed!
# (11,13) is #143 Destroyed!
# (1,4) is #144 Destroyed!
# (0,3) is #145 Destroyed!
# (9,11) is #146 Destroyed!
# (8,10) is #147 Destroyed!
# (7,9) is #148 Destroyed!
# (6,8) is #149 Destroyed!
# (5,7) is #150 Destroyed!
# (4,6) is #151 Destroyed!
# (2,4) is #152 Destroyed!
# (1,3) is #153 Destroyed!
# (0,2) is #154 Destroyed!
# (19,20) is #155 Destroyed!
# (0,0) is #156 Destroyed!
# (1,1) is #157 Destroyed!
# (3,3) is #158 Destroyed!
# (4,4) is #159 Destroyed!
# (6,6) is #160 Destroyed!
# (8,8) is #161 Destroyed!
# (10,10) is #162 Destroyed!
# (5,4) is #163 Destroyed!
# (6,5) is #164 Destroyed!
# (14,14) is #165 Destroyed!
# (3,1) is #166 Destroyed!
# (4,2) is #167 Destroyed!
# (5,3) is #168 Destroyed!
# (6,4) is #169 Destroyed!
# (3,0) is #170 Destroyed!
# (12,11) is #171 Destroyed!
# (13,12) is #172 Destroyed!
# (7,4) is #173 Destroyed!
# (17,17) is #174 Destroyed!
# (6,2) is #175 Destroyed!
# (12,10) is #176 Destroyed!
# (7,3) is #177 Destroyed!
# (15,14) is #178 Destroyed!
# (6,1) is #179 Destroyed!
# (11,8) is #180 Destroyed!
# (7,2) is #181 Destroyed!
# (12,9) is #182 Destroyed!
# (7,1) is #183 Destroyed!
# (9,4) is #184 Destroyed!
# (11,7) is #185 Destroyed!
# (8,2) is #186 Destroyed!
# (15,13) is #187 Destroyed!
# (7,0) is #188 Destroyed!
# (12,8) is #189 Destroyed!
# (17,16) is #190 Destroyed!
# (10,4) is #191 Destroyed!
# (12,7) is #192 Destroyed!
# (11,5) is #193 Destroyed!
# (15,12) is #194 Destroyed!
# (9,1) is #195 Destroyed!
# (13,8) is #196 Destroyed!
# (12,6) is #197 Destroyed!
# (11,4) is #198 Destroyed!
# (9,0) is #199 Destroyed!
# ***** ---> Target Destroyed!!! <--- *****
# (19,19) is #200 Destroyed!
# (11,2) is #201 Destroyed!
# (12,4) is #202 Destroyed!
# (14,8) is #203 Destroyed!
# (15,10) is #204 Destroyed!
# (11,1) is #205 Destroyed!
# (17,14) is #206 Destroyed!
# (12,2) is #207 Destroyed!
# (15,9) is #208 Destroyed!
# (13,4) is #209 Destroyed!
# (18,16) is #210 Destroyed!
# (15,8) is #211 Destroyed!
# (17,13) is #212 Destroyed!
# (13,2) is #213 Destroyed!
# (16,10) is #214 Destroyed!
# (15,7) is #215 Destroyed!
# (13,1) is #216 Destroyed!
# (17,12) is #217 Destroyed!
# (15,5) is #218 Destroyed!
# (17,11) is #219 Destroyed!
# (18,14) is #220 Destroyed!
# (15,3) is #221 Destroyed!
# (17,10) is #222 Destroyed!
# (16,6) is #223 Destroyed!
# (16,5) is #224 Destroyed!
# (15,0) is #225 Destroyed!
# (16,2) is #226 Destroyed!
# (19,16) is #227 Destroyed!
# (16,0) is #228 Destroyed!
# (17,5) is #229 Destroyed!
# (18,10) is #230 Destroyed!
# (17,4) is #231 Destroyed!
# (19,15) is #232 Destroyed!
# (17,2) is #233 Destroyed!
# (18,8) is #234 Destroyed!
# (19,14) is #235 Destroyed!
# (19,13) is #236 Destroyed!
# (19,12) is #237 Destroyed!
# (18,2) is #238 Destroyed!
# (19,11) is #239 Destroyed!
# (18,0) is #240 Destroyed!
# (19,7) is #241 Destroyed!
# (19,6) is #242 Destroyed!
# (19,5) is #243 Destroyed!
# (19,4) is #244 Destroyed!
# (19,3) is #245 Destroyed!
# (19,2) is #246 Destroyed!
# (19,0) is #247 Destroyed!
# Sweep #1 Done. (247/328 Hits)
# (20,17) is #248 Destroyed!
# (23,12) is #249 Destroyed!
# (22,17) is #250 Destroyed!
# (22,21) is #251 Destroyed!
# (14,23) is #252 Destroyed!
# (10,23) is #253 Destroyed!
# (6,23) is #254 Destroyed!
# (2,23) is #255 Destroyed!
# (0,23) is #256 Destroyed!
# (17,21) is #257 Destroyed!
# (0,19) is #258 Destroyed!
# (4,19) is #259 Destroyed!
# (2,18) is #260 Destroyed!
# (2,17) is #261 Destroyed!
# (4,17) is #262 Destroyed!
# (4,15) is #263 Destroyed!
# (5,15) is #264 Destroyed!
# (6,14) is #265 Destroyed!
# (2,11) is #266 Destroyed!
# (10,15) is #267 Destroyed!
# (14,17) is #268 Destroyed!
# (6,11) is #269 Destroyed!
# (10,13) is #270 Destroyed!
# (6,9) is #271 Destroyed!
# (2,5) is #272 Destroyed!
# (18,19) is #273 Destroyed!
# (8,7) is #274 Destroyed!
# (4,1) is #275 Destroyed!
# (14,13) is #276 Destroyed!
# (5,0) is #277 Destroyed!
# (10,5) is #278 Destroyed!
# (14,11) is #279 Destroyed!
# (8,0) is #280 Destroyed!
# (10,3) is #281 Destroyed!
# (18,17) is #282 Destroyed!
# (14,7) is #283 Destroyed!
# (14,6) is #284 Destroyed!
# (15,6) is #285 Destroyed!
# (14,1) is #286 Destroyed!
# (18,11) is #287 Destroyed!
# (18,3) is #288 Destroyed!
# Sweep #2 Done. (288/328 Hits)
# (20,14) is #289 Destroyed!
# (15,21) is #290 Destroyed!
# (0,16) is #291 Destroyed!
# (0,13) is #292 Destroyed!
# (4,13) is #293 Destroyed!
# (8,13) is #294 Destroyed!
# (5,9) is #295 Destroyed!
# (16,17) is #296 Destroyed!
# (11,9) is #297 Destroyed!
# (17,15) is #298 Destroyed!
# (11,0) is #299 Destroyed!
# Sweep #3 Done. (299/328 Hits)
# (20,13) is #300 Destroyed!
# (12,21) is #301 Destroyed!
# (2,12) is #302 Destroyed!
# (5,11) is #303 Destroyed!
# (15,16) is #304 Destroyed!
# (8,5) is #305 Destroyed!
# (14,9) is #306 Destroyed!
# Sweep #4 Done. (306/328 Hits)
# (20,11) is #307 Destroyed!
# (1,21) is #308 Destroyed!
# (0,11) is #309 Destroyed!
# (2,9) is #310 Destroyed!
# (14,15) is #311 Destroyed!
# (5,1) is #312 Destroyed!
# (13,7) is #313 Destroyed!
# Sweep #5 Done. (313/328 Hits)
# (20,9) is #314 Destroyed!
# (20,21) is #315 Destroyed!
# (13,14) is #316 Destroyed!
# (12,5) is #317 Destroyed!
# Sweep #6 Done. (317/328 Hits)
# (20,8) is #318 Destroyed!
# (12,13) is #319 Destroyed!
# Sweep #7 Done. (319/328 Hits)
# (20,7) is #320 Destroyed!
# (11,12) is #321 Destroyed!
# Sweep #8 Done. (321/328 Hits)
# (20,4) is #322 Destroyed!
# (6,7) is #323 Destroyed!
# Sweep #9 Done. (323/328 Hits)
# (20,2) is #324 Destroyed!
# (5,6) is #325 Destroyed!
# Sweep #10 Done. (325/328 Hits)
# (20,1) is #326 Destroyed!
# (3,4) is #327 Destroyed!
# Sweep #11 Done. (327/328 Hits)
# (2,3) is #328 Destroyed!
# Sweep #12 Done. (328/328 Hits)
